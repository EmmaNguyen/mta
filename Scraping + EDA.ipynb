# %% [markdown]
# ## Scraping

# %%
ls data
# Out:
# turnstile_160910.txt

# %% [markdown]
# ## EDA

# %%
import graphlab as gl
gl.canvas.set_target('ipynb') # use IPython Notebook output for GraphLab Canvas

# %%
# Read data
sf = gl.SFrame.read_csv('data/turnstile_160910.txt')
sf.show()
# Out:
# Finished parsing file /home/mpn/Desktop/Zipfian/mta/data/turnstile_160910.txt
# Parsing completed. Parsed 100 lines in 1.38811 secs.
# Finished parsing file /home/mpn/Desktop/Zipfian/mta/data/turnstile_160910.txt
# Parsing completed. Parsed 194878 lines in 0.783633 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,str,str,str,str,str,str,str,str,int,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-7846a980be21> in <module>()
# ----> 1 sf.info()
#
# AttributeError: 'SFrame' object has no attribute 'info'

# %% [markdown]
# ## Play with Pandas + Numpy / Data Mungle

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# /home/mpn/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
ls data
# Out:
# turnstile_160813.txt  turnstile_160903.txt
# turnstile_160827.txt  turnstile_160910.txt

# %%
df1 = pd.read_csv('data/turnstile_160910.txt')
df2 = pd.read_csv('data/turnstile_160903.txt')
df3 = pd.read_csv('data/turnstile_160827.txt')
df4 = pd.read_csv('data/turnstile_160813.txt')

# %%
print df1.info()
print df2.info()
print df3.info()
print df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194878 entries, 0 to 194877
# Data columns (total 11 columns):
# C/A                                                                     194878 non-null object
# UNIT                                                                    194878 non-null object
# SCP                                                                     194878 non-null object
# STATION                                                                 194878 non-null object
# LINENAME                                                                194878 non-null object
# DIVISION                                                                194878 non-null object
# DATE                                                                    194878 non-null object
# TIME                                                                    194878 non-null object
# DESC                                                                    194878 non-null object
# ...

# %%
print df1.describe()
print "--------------"
print df2.describe()
# Out:
#             ENTRIES  \
# count  1.948780e+05
# mean   3.552272e+07
# std    1.957628e+08
# min    0.000000e+00
# 25%    5.784720e+05
# 50%    2.629012e+06
# 75%    6.576240e+06
# max    2.147374e+09
#
#        EXITS
# count                                       1.948780e+05
# mean                                        2.863326e+07
# std                                         1.772758e+08
# min                                         0.000000e+00
# 25%                                         2.958088e+05
# 50%                                         1.524246e+06
# 75%                                         4.695386e+06
# max                                         2.087387e+09
# --------------
#             ENTRIES  \
# count  1.931390e+05
# mean   3.526388e+07
# std    1.946014e+08
# min    0.000000e+00
# 25%    5.739535e+05
# 50%    2.621946e+06
# 75%    6.571109e+06
# max    2.114808e+09
#
#        EXITS
# count                                       1.931390e+05
# ...

# %%
print df1.head()
print "------------------------"
print df2.head()
print "------------------------"
print df3.head()
print "------------------------"
print df4.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST   NQR456      BMT  09/03/2016  00:00:00
# 1  A002  R051  02-00-00   59 ST   NQR456      BMT  09/03/2016  04:00:00
# 2  A002  R051  02-00-00   59 ST   NQR456      BMT  09/03/2016  08:00:00
# 3  A002  R051  02-00-00   59 ST   NQR456      BMT  09/03/2016  12:00:00
# 4  A002  R051  02-00-00   59 ST   NQR456      BMT  09/03/2016  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  5808846
# 1  REGULAR  5808877
# 2  REGULAR  5808900
# 3  REGULAR  5808997
# 4  REGULAR  5809234
#
#    EXITS
# 0                                            1968971
# 1                                            1968979
# 2                                            1969008
# 3                                            1969079
# 4                                            1969139
# ------------------------
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=194878, step=1)

# %%
df.columns
# Out:
# Index([u'C/A', u'UNIT', u'SCP', u'STATION', u'LINENAME', u'DIVISION', u'DATE',
#        u'TIME', u'DESC', u'ENTRIES',
#        u'EXITS                                                               '],
#       dtype='object')

# %%
df.values
# Out:
# array([['A002', 'R051', '02-00-00', ..., 'REGULAR', 5808846, 1968971],
#        ['A002', 'R051', '02-00-00', ..., 'REGULAR', 5808877, 1968979],
#        ['A002', 'R051', '02-00-00', ..., 'REGULAR', 5808900, 1969008],
#        ...,
#        ['TRAM2', 'R469', '00-05-01', ..., 'REGULAR', 5554, 271],
#        ['TRAM2', 'R469', '00-05-01', ..., 'REGULAR', 5554, 271],
#        ['TRAM2', 'R469', '00-05-01', ..., 'REGULAR', 5554, 271]], dtype=object)

# %%
# pd.pivot_table(df, values='EXITS', index=['STATION', 'LINENAME'], columns=['DATE'])

# %%
# Convert Date to timestamp
# https://docs.python.org/3/library/datetime.html

df1.DATE.dtype
a = pd.to_datetime(df1.DATE)
a[1].day
a[1].date()
a[1].hour
print a.apply(lambda x: x.day)
# Out:
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
# 5         3
# 6         4
# 7         4
# 8         4
# 9         4
# 10        4
# 11        4
# 12        5
# 13        5
# 14        5
# 15        5
# 16        5
# 17        5
# 18        6
# 19        6
# 20        6
# 21        6
# 22        6
# 23        6
# 24        7
# 25        7
# 26        7
# 27        7
# 28        7
# 29        7
#          ..
# 194848    5
# 194849    5
# 194850    5
# 194851    5
# 194852    5
# 194853    5
# 194854    6
# 194855    6
# 194856    6
# 194857    6
# 194858    6
# 194859    6
# 194860    7
# 194861    7
# 194862    7
# 194863    7
# 194864    7
# 194865    7
# 194866    8
# 194867    8
# 194868    8
# 194869    8
# 194870    8
# 194871    8
# 194872    9
# 194873    9
# 194874    9
# 194875    9
# 194876    9
# 194877    9
# Name: DATE, dtype: int64
